# %%
import torch
from torch.distributions import Bernoulli, Categorical, Beta, NegativeBinomial, Uniform, Normal
from tqdm import tqdm
from scipy.optimize import minimize
from scipy.optimize import differential_evolution

# %%
def generate_agents_var1(probability_client=0.1, buy_intention_concentration1=0.5, buy_intention_concentration2=0.5,
                    nr_visits_total_count=20, nr_visits_probs=0.8, nr_samples=1000):
    '''
    Generate agents knowing:
        - buy_intention (float in (0,1)): intention of buying
        - client (boolean): whether is a client or not
        - nr_visits (int): number of visits done beforehand
    '''
    buy_intention = Beta(buy_intention_concentration1, buy_intention_concentration2)
    client = Bernoulli(probability_client)
    nr_visits = NegativeBinomial(total_count=nr_visits_total_count, probs=nr_visits_probs)

    buy_intention_samples = buy_intention.sample((nr_samples,))
    client_samples = client.sample((nr_samples,))    
    nr_visits_samples = nr_visits.sample((nr_samples,))

    agents_tensor = torch.stack((buy_intention_samples, client_samples, nr_visits_samples), dim=1)

    return agents_tensor

# %%
def generate_agents_var2():
    '''
    tech = Bernoulli(0.7)
    age = Categorical(probs=torch.tensor([0.25, 0.6, 0.15]))
    discounts = Uniform(0.3, 0.8)

    tech_samples = tech.sample((10000,))
    age_samples = age.sample((10000,))
    '''
    pass

# %%
def will_buy_linear(agent, discount, weights, threshold=0.5):
    """
    Predict whether a client will buy something based on their characteristics.
    
    Args:
    - agent (tensor): Buy intention, whether the person is a client or not and number of visits
    - discount (float): Discount observed by the client.
    - weights (dict): Weights for each of the variables in the model.
    - threshold (float): Decision threshold for making a purchase.
    
    Returns:
    - buy_decision (bool): True if the client is predicted to buy, False otherwise.
    """
    
    weighted_sum = (
        weights['buy_intention'] * agent[0] +
        weights['client'] * agent[1] +
        weights['nr_visits'] * agent[2] / 100 +
        weights['discount'] * discount 
    )
    
    buy_probability = torch.sigmoid(torch.tensor(weighted_sum))
    
    buy_decision = buy_probability.item() > threshold
    
    return buy_decision

# %%
def will_buy_polynomial(agent, discount, weights, threshold=0.5):
    """
    Polynomial model for predicting purchase decision based on input features.
    
    Args:
    - agent (tensor): Buy intention, whether the person is a client or not and number of visits
    - discount (float): Discount observed by the client.
    - weights (dict): Weights for each of the variables in the model.
    - threshold (float): Decision threshold for making a purchase.
    
    Returns:
    - buy_decision (bool): True if the client is predicted to buy, False otherwise.
    """
    # de pus un polinom pt fiecare feature
    weighted_sum = (
        weights['buy_intention'] * (agent[0] ** 3) +
        weights['nr_visits'] * ((agent[2] / 100) ** 2) +
        weights['client'] * agent[1] +
        weights['discount'] * discount 
    )
    
    buy_probability = torch.sigmoid(torch.tensor(weighted_sum))
    
    buy_decision = buy_probability.item() > threshold
    
    return buy_decision

# %%
def compute_buy_rate_per_day(weights, discount_sample, nr_agents_mean=17000, nr_agents_std=5000, model = 'linear', threshold=0.5):
    nr_agents_distribution = Normal(nr_agents_mean, nr_agents_std)
    # discounts_distribution = Uniform(0.3, 0.8)

    nr_agents = int(nr_agents_distribution.sample())
    agents = generate_agents_var1(nr_samples=nr_agents)
    # discount_sample = discounts_distribution.sample()

    buyers = []
    for i in range(nr_agents):
        if model == 'linear':
            buy_decision = will_buy_linear(agents[i], discount_sample, weights, threshold=threshold)
        elif model == 'polynomial':
            buy_decision = will_buy_polynomial(agents[i], discount_sample, weights, threshold=threshold)
        else:
            return "Model unrecognized"
        buyers.append(buy_decision)
        
    return sum(buyers)/len(buyers) * 100

# %% [markdown]
# ### Check if a client is going to buy

# %%
# Example weights (tune these based on your application)
weights = {
    'buy_intention': 2,
    'client': 1.5,
    'nr_visits': 0.5,
    'discount': 1,
}

# Predict whether the client will buy
ex_agent = generate_agents_var1(nr_samples=1)[0]
discounts = Uniform(0.3, 0.8)
ex_discount = discounts.sample()
buy_decision = will_buy_linear(ex_agent, ex_discount, weights)

print(f"Client will buy: {buy_decision}")
# Out:
# Client will buy: True
# C:\Users\aledragomir\AppData\Local\Temp\ipykernel_3544\2607145893.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   buy_probability = torch.sigmoid(torch.tensor(weighted_sum))

# %% [markdown]
# ### Check buy rate

# %%
weights = {
    'client': 0.05,
    'buy_intention': 0.1,
    'discount': -0.1,
    'nr_visits': 0.1
}
optimal_weights = {
    'client': 0.10336490701521983, 
    'buy_intention': -1.659139677733452, 
    'discount': 1.7634846657437528, 
    'nr_visits': -1.6603175669790198
}
optimal_weights2 = {
    'client': 0.34609360002695433, 
    'buy_intention': 2.613208217330935, 
    'discount': -0.9798212343384489, 
    'nr_visits': -2.744351905215244
}
optimal_weights3 = {
    'client': 2.114004995094768, 
    'buy_intention': 1.056666893728789, 
    'discount': -2.8883069864678266, 
    'nr_visits': -1.7351176018905805
}
# Current buy rate: 0.911925175370226

buyers = compute_buy_rate_per_day(weights=optimal_weights3, threshold=0.5, model='polynomial')
buyers
# Out:
# C:\Users\aledragomir\AppData\Local\Temp\ipykernel_3544\1523727861.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   buy_probability = torch.sigmoid(torch.tensor(weighted_sum))
# 1.0625286653416908

# %% [markdown]
# ### Optimize weights to reach 0.8% buy rate

# %%
def optimize_weights(nr_agents, target_sum, threshold=0.5, model = 'linear'):
    """
    Adjust the weights to achieve the target sum of buy_decisions across the samples.
    
    Args:
    - num_samples (int): Number of samples to generate.
    - target_sum (int): Target sum of buy_decisions.
    - initial_weights (dict): Initial weights for the model.
    - threshold (float): Decision threshold for making a purchase.
    
    Returns:
    - optimal_weights (dict): Weights adjusted to achieve the target sum.
    """
    
    def objective_function(weights_array):
        weights = {
            'client': weights_array[0],
            'buy_intention': weights_array[1],
            'discount': weights_array[2],
            'nr_visits': weights_array[3]
        }
        
        # Generate samples and calculate the sum of buy_decisions
        agents = generate_agents_var1(nr_samples=nr_agents)
        discounts_distribution = Uniform(0.3, 0.8)
        

        buy_decisions = []
        for i in range(nr_agents):
            discount_sample = discounts_distribution.sample()
            if model == 'linear':
                buy_decision = will_buy_linear(agents[i], discount_sample, weights, threshold=threshold)    
            elif model == 'polynomial':
                buy_decision = will_buy_polynomial(agents[i], discount_sample, weights, threshold=threshold)
            buy_decisions.append(buy_decision)
        
        sum_buy_decisions = sum(buy_decisions)
        
        loss = (sum_buy_decisions - target_sum) / len(buy_decisions) 
        print(f"Current loss: {loss}, Weights: {weights}")  
        buy_rate = compute_buy_rate_per_day(weights=weights, model=model)
        print(f"Current buy rate: {buy_rate}")
        return loss
    
    # # Initial weights in array form
    # initial_weights_array = [
    #     initial_weights['client'],
    #     initial_weights['buy_intention'],
    #     initial_weights['discount'],
    #     initial_weights['nr_visits']
    # ]
    
    # Optimize the weights to minimize the objective function
    # result = minimize(objective_function, initial_weights_array, method='Powell')
    # Define bounds for each weight
    bounds = [(-3, 3), (-3, 3), (-3, 3), (-3, 3)]

    # Run the differential evolution algorithm
    result = differential_evolution(objective_function, bounds)
    
    # Convert the result back to a dictionary
    optimal_weights = {
        'client': result.x[0],
        'buy_intention': result.x[1],
        'discount': result.x[2],
        'nr_visits': result.x[3]
    }
    
    return optimal_weights

# # Initial weights (can be random or based on intuition)
# initial_weights = {
#     'client': 1,
#     'buy_intention': 0.58,
#     'discount': 0.35,
#     'nr_visits': 0.5
# }

# %%
optimal_weights = optimize_weights(nr_agents=10000, target_sum=80, threshold=0.5, model='polynomial')

print("Optimal Weights:", optimal_weights)
# Out:
# C:\Users\aledragomir\AppData\Local\Temp\ipykernel_3544\1523727861.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   buy_probability = torch.sigmoid(torch.tensor(weighted_sum))
# Current loss: 0.2327, Weights: {'client': 1.3185936343733788, 'buy_intention': -2.505018444327088, 'discount': -2.9104386569795224, 'nr_visits': 2.04223998611842}
# Current buy rate: 15.841584158415841
# Current loss: 0.992, Weights: {'client': 2.660489894719282, 'buy_intention': 2.5930214099375584, 'discount': 0.5088327413846947, 'nr_visits': 0.021609047993487396}
# Current buy rate: 100.0
# Current loss: -0.008, Weights: {'client': -2.450152298846887, 'buy_intention': 0.3258241949781717, 'discount': -1.8729081963876695, 'nr_visits': -2.9817531311631407}
# Current buy rate: 0.0
# Current loss: 0.0464, Weights: {'client': -2.8349795152125274, 'buy_intention': 1.4310098624329213, 'discount': -0.7160874915240494, 'nr_visits': -2.036574121505409}
# Current buy rate: 5.753870078461865
# Current loss: 0.4054, Weights: {'client': -0.8100801162813325, 'buy_intention': -2.741062477934441, 'discount': 0.2451953656421615, 'nr_visits': 0.14450006881682298}
# Current buy rate: 41.63994743758213
# Current loss: 0.9868, Weights: {'client': 0.14046656788323486, 'buy_intention': -0.20694757814483977, 'discount': 0.16448311036088792, 'nr_visits': 0.4999248079867584}
# Current buy rate: 98.95550732501357
# Current loss: 0.0771, Weights: {'client': 2.820249315660066, 'buy_intention': -2.989878260239136, 'discount': -2.8624024845597478, 'nr_visits': 0.9124703550857547}
# Current buy rate: 7.546007546007546
# Current loss: 0.0004, Weights: {'client': -1.7982609337248403, 'buy_intention': 1.3568628340447044, 'discount': -1.6348849949075643, 'nr_visits': -1.932274248315141}
# Current buy rate: 0.8421664004646435
# Current loss: 0.0251, Weights: {'client': 1.8158158086811373, 'buy_intention': -1.2262209197378535, 'discount': -1.0182955104310039, 'nr_visits': -1.778485241198928}
# Current buy rate: 3.4380776340110906
# Current loss: 0.6335, Weights: {'client': -0.2281236980274276, 'buy_intention': 2.2498604467897385, 'discount': 1.1970002801921042, 'nr_visits': -1.3107681161381195}
# Current buy rate: 76.09858259471184
# Current loss: 0.6693, Weights: {'client': -0.3455684661602135, 'buy_intention': -0.7171772374383347, 'discount': 1.6175703061620352, 'nr_visits': -0.6730710696408029}
# Current buy rate: 51.21508600284046
# Current loss: -0.0041, Weights: {'client': -0.999086817701652, 'buy_intention': 0.14114873459219957, 'discount': -1.9859100954250064, 'nr_visits': 0.3809047993465975}
# Current buy rate: 0.008187996397281586
# Current loss: 0.992, Weights: {'client': -0.16212521568036986, 'buy_intention': 1.922777269674325, 'discount': 1.2495619800034352, 'nr_visits': 0.2763374858256058}
# Current buy rate: 100.0
# Current loss: 0.0913, Weights: {'client': 2.2904105525946274, 'buy_intention': 0.7103096596042775, 'discount': -1.511737092694434, 'nr_visits': -0.5025589317141892}
# Current buy rate: 9.64996568291009
# Current loss: 0.023, Weights: {'client': 1.774504301790666, 'buy_intention': -1.6753777934019087, 'discount': -0.08852660752404762, 'nr_visits': -2.64296647518503}
# Current buy rate: 3.2077433805295574
# Current loss: 0.422, Weights: {'client': 2.3966781826233037, 'buy_intention': -2.2699006097277996, 'discount': -2.5916244320641533, 'nr_visits': 2.612860021336449}
# Current buy rate: 38.40811602097093
# Current loss: 0.9385, Weights: {'client': -2.0743959697581738, 'buy_intention': 2.3806498322089475, 'discount': 1.5484096418133757, 'nr_visits': 0.8982146676031344}
# Current buy rate: 93.36685360665248
# Current loss: 0.7684, Weights: {'client': 1.6352229379901417, 'buy_intention': -2.055181921730659, 'discount': 2.8267168359321317, 'nr_visits': -0.3861832233440373}
# Current buy rate: 82.22389937106918
# Current loss: 0.0647, Weights: {'client': -1.5133294354572513, 'buy_intention': 1.2694871756649442, 'discount': 0.3907242682847294, 'nr_visits': -2.846204022487975}
# Current buy rate: 8.610964879296082
# Current loss: 0.0364, Weights: {'client': 0.7941497526692682, 'buy_intention': 0.4972635033300583, 'discount': -0.6535540476929828, 'nr_visits': -1.0671188222384422}
# Current buy rate: 6.1351139041633935
# Current loss: 0.8212, Weights: {'client': -1.8686375317520603, 'buy_intention': 1.0681260784459043, 'discount': -0.4526457518473085, 'nr_visits': 0.6635832974862488}
# Current buy rate: 77.18772192850943
# Current loss: 0.6084, Weights: {'client': -2.5891851321924664, 'buy_intention': -1.940745971980589, 'discount': -1.3789649463309015, 'nr_visits': 2.8471986440137664}
# Current buy rate: 62.02544529262086
# Current loss: 0.992, Weights: {'client': 2.9096450990705, 'buy_intention': 2.4325417687557933, 'discount': 2.1275472288544393, 'nr_visits': 0.7779376857857789}
# Current buy rate: 100.0
# Current loss: 0.3269, Weights: {'client': -2.2908027926904673, 'buy_intention': -2.8690216361923744, 'discount': 1.447517657051091, 'nr_visits': -0.8484862199521896}
# Current buy rate: 31.245784757683786
# Current loss: 0.6146, Weights: {'client': 0.4854109507464961, 'buy_intention': -1.8934913595546847, 'discount': -1.148177002668567, 'nr_visits': 2.1371287807692023}
# Current buy rate: 52.44745575221239
# Current loss: -0.008, Weights: {'client': 0.3150237084507066, 'buy_intention': -0.9488422929236839, 'discount': -2.181696910943127, 'nr_visits': -1.2481108694603962}
# Current buy rate: 0.0
# Current loss: 0.8488, Weights: {'client': -2.785768917789146, 'buy_intention': -0.6894426258476566, 'discount': -0.5731854634386222, 'nr_visits': 2.5563571957969398}
# Current buy rate: 88.14168770560784
# Current loss: 0.9221, Weights: {'client': -2.313054222052662, 'buy_intention': 1.5190403392496392, 'discount': -0.14620144871859564, 'nr_visits': 2.2359927745155463}
# Current buy rate: 93.00251783466219
# Current loss: 0.992, Weights: {'client': 2.7528029053049368, 'buy_intention': 2.750287938057261, 'discount': 2.7353484411102795, 'nr_visits': 1.4498760914902755}
# Current buy rate: 100.0
# Current loss: 0.992, Weights: {'client': 1.5627080236157582, 'buy_intention': 0.680719529652295, 'discount': 2.6418993500232144, 'nr_visits': 1.7647017373525713}
# Current buy rate: 100.0
# Current loss: -0.008, Weights: {'client': -1.1784877783543333, 'buy_intention': -0.8513870765512097, 'discount': -2.033630857696679, 'nr_visits': -2.7507093399271767}
# Current buy rate: 0.0
# Current loss: 0.8229, Weights: {'client': 0.20214162726910478, 'buy_intention': -2.361367497891341, 'discount': 1.0592748282132036, 'nr_visits': 1.9877253843430391}
# Current buy rate: 86.98889198550782
# Current loss: 0.8664, Weights: {'client': -1.3076761795761254, 'buy_intention': 0.9130238407875302, 'discount': 1.815735651812578, 'nr_visits': -0.7308434159614448}
# Current buy rate: 88.50023319341729
# Current loss: 0.9624, Weights: {'client': 0.9440539352949135, 'buy_intention': 1.1768564335150546, 'discount': 2.506489995439111, 'nr_visits': -0.9133352403329877}
# Current buy rate: 99.15712468193384
# Current loss: 0.7739, Weights: {'client': -1.2690809623656727, 'buy_intention': -1.5681526094418747, 'discount': -0.3817657508800122, 'nr_visits': 2.441996135804491}
# Current buy rate: 80.29643353404354
# Current loss: 0.1743, Weights: {'client': -1.6847202388878666, 'buy_intention': 0.842490912605399, 'discount': 1.31184983088876, 'nr_visits': -2.553055177703193}
# Current buy rate: 25.756656927063233
# Current loss: -0.008, Weights: {'client': 0.6039485397793067, 'buy_intention': -1.4755711233151307, 'discount': -2.620494786810828, 'nr_visits': -0.16632821582014}
# Current buy rate: 0.0
# Current loss: 0.0252, Weights: {'client': 1.9149887219477228, 'buy_intention': 1.7361955742029398, 'discount': -2.7228689827987713, 'nr_visits': -2.1990358991753767}
# Current buy rate: 1.8037350655376407
# Current loss: -0.008, Weights: {'client': 0.5791140661360055, 'buy_intention': -0.5409522394350355, 'discount': -1.4283626566947207, 'nr_visits': -1.197904198254532}
# Current buy rate: 0.0
# Current loss: 0.992, Weights: {'client': 2.4716065846300133, 'buy_intention': 1.80945846364554, 'discount': 0.04350542286370529, 'nr_visits': 1.135152481788841}
# Current buy rate: 100.0
# Current loss: 0.7891, Weights: {'client': -1.9652796668924233, 'buy_intention': 2.047598401731423, 'discount': 0.7238645972187789, 'nr_visits': -0.4643980312603049}
# Current buy rate: 75.07427776724192
# Current loss: 0.9492, Weights: {'client': -1.0440142600831197, 'buy_intention': -1.1129804126344292, 'discount': 0.9835493688378374, 'nr_visits': 1.8730469290700869}
# Current buy rate: 97.23917249590713
# Current loss: 0.4447, Weights: {'client': -0.6091524923712789, 'buy_intention': -1.020089399720432, 'discount': 2.3652383239906074, 'nr_visits': -1.5886671780238188}
# Current buy rate: 29.399441340782122
# Current loss: 0.0471, Weights: {'client': 1.4751067145694625, 'buy_intention': -1.7441366434269219, 'discount': 0.47375354552100224, 'nr_visits': -1.8659863645551271}
# Current buy rate: 4.900690846286701
# Current loss: 0.3541, Weights: {'client': 2.0902352225263847, 'buy_intention': 2.1929130881689254, 'discount': -0.2528259828667929, 'nr_visits': -1.4177602359036947}
# Current buy rate: 35.639718378247146
# Current loss: 0.6551, Weights: {'client': 1.0723759192891518, 'buy_intention': -0.010426091505716495, 'discount': -2.229030189402468, 'nr_visits': 2.3506445243560177}
# Current buy rate: 51.508263193463165
# Current loss: -0.0079, Weights: {'client': 0.8100141129544265, 'buy_intention': -0.43261193200016956, 'discount': -1.2193544420802649, 'nr_visits': -2.4422891663580897}
# Current buy rate: 0.012742099898063202
# Current loss: 0.9505, Weights: {'client': -1.4631455182751185, 'buy_intention': 2.894783974752108, 'discount': 0.8866602602905078, 'nr_visits': 1.0036325042376688}
# Current buy rate: 96.66764619453423
# Current loss: 0.6064, Weights: {'client': 1.2120953609637746, 'buy_intention': 2.9292298893352586, 'discount': -2.3156514304613207, 'nr_visits': 1.2482935138652897}
# Current buy rate: 68.15903775476112
# Current loss: 0.9806, Weights: {'client': -0.7774094781006663, 'buy_intention': -2.1092953160947303, 'discount': 2.9241324136712747, 'nr_visits': 2.7164334657530866}
# Current buy rate: 99.92571582928147
# Current loss: -0.008, Weights: {'client': -2.1848403444162217, 'buy_intention': -1.3906333445241987, 'discount': -2.4570225054802908, 'nr_visits': -0.023054055808711005}
# Current buy rate: 0.0
# Current loss: 0.992, Weights: {'client': 2.1957019839335654, 'buy_intention': -0.19948406516332817, 'discount': 2.2109473453182202, 'nr_visits': 1.3374293153203511}
# Current buy rate: 100.0
# Current loss: 0.5584, Weights: {'client': -2.9313415195810126, 'buy_intention': 2.661892125224809, 'discount': 2.0143366686934803, 'nr_visits': -2.209786147458594}
# Current buy rate: 71.02856818310899
# Current loss: -0.008, Weights: {'client': 0.0012825526611401905, 'buy_intention': 0.27617377207640126, 'discount': -0.8314098821074084, 'nr_visits': -1.6582287940846092}
# Current buy rate: 0.0
# Current loss: 0.0475, Weights: {'client': 2.517456244507161, 'buy_intention': 0.06713537572609307, 'discount': -1.7628605765231253, 'nr_visits': -2.376610500829078}
# Current buy rate: 4.098820887142055
# Current loss: 0.9891, Weights: {'client': -0.5321678368900064, 'buy_intention': -0.37674624064286055, 'discount': 0.689508026543336, 'nr_visits': 1.655038283448688}
# Current buy rate: 99.94801266600501
# Current loss: 0.992, Weights: {'client': -0.09679362075888198, 'buy_intention': 1.63722198773367, 'discount': 1.7081049261689012, 'nr_visits': 0.5478665349829981}
# Current buy rate: 100.0
# Current loss: 0.9027, Weights: {'client': -2.6880704130089614, 'buy_intention': -2.6277959682026792, 'discount': 2.4308226948777802, 'nr_visits': 2.929300907138738}
# Current buy rate: 93.359586132345
# Current loss: 0.1041, Weights: {'client': 1.1737332282883048, 'buy_intention': 0.5248937433895444, 'discount': -0.9661115794558517, 'nr_visits': -0.2958913501648346}
# Current buy rate: 10.189757336343115
# Current loss: 0.8572, Weights: {'client': -0.4245599254690505, 'buy_intention': -2.4045418423796074, 'discount': 1.9587791900140317, 'nr_visits': 1.5988708054892988}
# Current buy rate: 81.4221408407721
# Current loss: 0.0095, Weights: {'client': -1.3355538217136653, 'buy_intention': 1.5342102706231922, 'discount': -1.8729081963876695, 'nr_visits': -1.5719445731712987}
# Current buy rate: 5.876180482686253
# Current loss: -0.008, Weights: {'client': -2.8009088312683073, 'buy_intention': -0.737707037423874, 'discount': -1.2319707412032863, 'nr_visits': -1.2411701856889858}
# Current buy rate: 0.0
# Current loss: 0.054, Weights: {'client': 1.3185936343733788, 'buy_intention': -2.505018444327088, 'discount': -0.8002533715028297, 'nr_visits': -0.0033905018283664212}
# Current buy rate: 6.487695749440715
# Current loss: 0.4862, Weights: {'client': 1.261241996325989, 'buy_intention': 1.4446014230420496, 'discount': -0.7160874915240494, 'nr_visits': 0.12271833268094712}
# Current buy rate: 45.80895079535152
# Current loss: 0.4926, Weights: {'client': -1.4593172652731956, 'buy_intention': -0.7132147262620305, 'discount': 0.2451953656421615, 'nr_visits': 0.00876009103099018}
# Current buy rate: 51.00082392284205
# Current loss: 0.6921, Weights: {'client': 2.7311669055833976, 'buy_intention': 1.1747897693526186, 'discount': 0.16448311036088792, 'nr_visits': -0.2319299542398996}
# Current buy rate: 61.54494855793558
# Current loss: 0.5656, Weights: {'client': -1.2644668562395123, 'buy_intention': 0.8431145247293197, 'discount': -2.738440986888186, 'nr_visits': 2.382765624586532}
# Current buy rate: 71.05180533751962
# Current loss: -0.008, Weights: {'client': -2.755925251400252, 'buy_intention': -1.0516198968774808, 'discount': -2.882850538265977, 'nr_visits': -2.4997284907191197}
# Current buy rate: 0.0
# Current loss: 0.2383, Weights: {'client': -1.853943183098206, 'buy_intention': 2.662879175783482, 'discount': -1.0182955104310039, 'nr_visits': -1.4469534721658905}
# Current buy rate: 22.36925015752993
# Current loss: 0.395, Weights: {'client': 1.3471378976858004, 'buy_intention': 2.2498604467897385, 'discount': 1.1970002801921042, 'nr_visits': -2.545400589567685}
# Current buy rate: 37.35224586288416
# Current loss: 0.992, Weights: {'client': -0.3710843893940522, 'buy_intention': -0.31734248145960375, 'discount': 1.6175703061620352, 'nr_visits': 0.7160231171943738}
# Current buy rate: 100.0
# Current loss: 0.0117, Weights: {'client': 1.225925378694766, 'buy_intention': 0.14114873459219957, 'discount': -0.814420807097769, 'nr_visits': -2.04493403821377}
# Current buy rate: 2.960201239780792
# Current loss: 0.992, Weights: {'client': -0.16212521568036986, 'buy_intention': 1.922777269674325, 'discount': 1.2495619800034352, 'nr_visits': 0.14567428596947707}
# Current buy rate: 100.0
# Current loss: 0.6662, Weights: {'client': 2.2904105525946274, 'buy_intention': 1.8552797353039456, 'discount': 1.5507009304820385, 'nr_visits': -1.5962281770201339}
# Current buy rate: 77.4905818334031
# Current loss: -0.008, Weights: {'client': -2.7180826206764124, 'buy_intention': 0.17398204968385467, 'discount': -2.5088756940938315, 'nr_visits': -2.64296647518503}
# Current buy rate: 0.0
# Current loss: 0.2483, Weights: {'client': -2.650218433216218, 'buy_intention': 1.6201685281396663, 'discount': -1.4324399479789345, 'nr_visits': -0.15707920031938483}
# Current buy rate: 18.026032959159302
# Current loss: 0.0759, Weights: {'client': -2.0743959697581738, 'buy_intention': -1.4521999077747103, 'discount': -1.7217386068161928, 'nr_visits': 0.8982146676031344}
# Current buy rate: 3.4241788958770094
# Current loss: 0.9785, Weights: {'client': -0.5388642946609732, 'buy_intention': -0.5492488900671075, 'discount': 1.977289725968396, 'nr_visits': 0.007825915073433665}
# Current buy rate: 98.73297275641025
# Current loss: 0.0131, Weights: {'client': -1.4714534465413365, 'buy_intention': 1.2944872862449466, 'discount': -1.111577364985528, 'nr_visits': -1.9026332393119558}
# Current buy rate: 5.1110491590000935
# Current loss: -0.008, Weights: {'client': -0.38332175579726213, 'buy_intention': -0.0651661822093883, 'discount': -2.244902623467389, 'nr_visits': -2.821234295053753}
# Current buy rate: 0.0
# Current loss: 0.2099, Weights: {'client': -1.5112752821737083, 'buy_intention': -1.6747893197196653, 'discount': -0.7536730315541178, 'nr_visits': 0.6635832974862488}
# Current buy rate: 30.701576004067103
# Current loss: 0.8684, Weights: {'client': 2.925963770907315, 'buy_intention': 0.41127551028802034, 'discount': -0.963446450739917, 'nr_visits': 1.3411647230459256}
# Current buy rate: 89.88671660880686
# Current loss: 0.3564, Weights: {'client': -1.6113790683049776, 'buy_intention': 2.4325417687557933, 'discount': 1.41364253708722, 'nr_visits': -2.6517489528364857}
# Current buy rate: 28.29314378261652
# Current loss: 0.1333, Weights: {'client': 1.3094736898402415, 'buy_intention': 1.2401203800681957, 'discount': 0.20932904202765368, 'nr_visits': -2.4929341696879006}
# Current buy rate: 14.040607931607694
# Current loss: -0.008, Weights: {'client': -2.7907490437255578, 'buy_intention': -0.0450072075748843, 'discount': -1.148177002668567, 'nr_visits': -2.1680091510959754}
# Current buy rate: 0.0
# Current loss: 0.8891, Weights: {'client': -2.54691719339309, 'buy_intention': 1.2211288400134548, 'discount': 1.6980474344743572, 'nr_visits': -0.3831950398721593}
# Current buy rate: 89.69782150386507
# Current loss: 0.0731, Weights: {'client': -2.145244444934404, 'buy_intention': 0.7406524942876844, 'discount': -0.5731854634386222, 'nr_visits': -0.6592238585528647}
# Current buy rate: 13.94813885403597
# Current loss: 0.8998, Weights: {'client': -2.4790803718657393, 'buy_intention': 1.5190403392496392, 'discount': -0.14620144871859564, 'nr_visits': 1.362779813639372}
# Current buy rate: 90.7936507936508
# Current loss: 0.992, Weights: {'client': 2.7528029053049368, 'buy_intention': 0.010034714175943371, 'discount': 2.7353484411102795, 'nr_visits': 1.4498760914902755}
# Current buy rate: 100.0
# Current loss: -0.0066, Weights: {'client': 1.3321961029126603, 'buy_intention': 0.680719529652295, 'discount': -2.665199390149596, 'nr_visits': -2.6240483215053363}
# Current buy rate: 0.08250068750572921
# Current loss: -0.008, Weights: {'client': -1.817651142963805, 'buy_intention': -0.8513870765512097, 'discount': -2.033630857696679, 'nr_visits': -2.7329039587795605}
# Current buy rate: 0.0
# Current loss: 0.992, Weights: {'client': -0.31764706790670083, 'buy_intention': -0.022886161997125898, 'discount': 1.521788269372367, 'nr_visits': 1.513813131386905}
# Current buy rate: 100.0
# Current loss: 0.992, Weights: {'client': 2.902725786637325, 'buy_intention': 1.5997971192526463, 'discount': 1.0330021704739107, 'nr_visits': 1.7339807413510393}
# Current buy rate: 100.0
# Current loss: 0.3779, Weights: {'client': -1.8072035095401793, 'buy_intention': -2.091281005723033, 'discount': 2.506489995439111, 'nr_visits': -1.5534300537350108}
# Current buy rate: 48.62096992684909
# Current loss: 0.5291, Weights: {'client': 1.4918189137638933, 'buy_intention': 2.4833028843418337, 'discount': -0.3817657508800122, 'nr_visits': -0.2407662554573683}
# Current buy rate: 55.860655737704924
# Current loss: 0.4207, Weights: {'client': -1.6847202388878666, 'buy_intention': 2.4520286818704173, 'discount': -2.9013048286979615, 'nr_visits': 1.3941133329051822}
# Current buy rate: 26.941899861965112
# Current loss: 0.3968, Weights: {'client': 0.9461330586917585, 'buy_intention': -1.4755711233151307, 'discount': 1.998962348447268, 'nr_visits': -1.4719311125428005}
# Current buy rate: 59.87871437234688
# Current loss: -0.008, Weights: {'client': -0.3593787856965085, 'buy_intention': -0.9219226311324611, 'discount': -2.383669344773587, 'nr_visits': -1.6023986964569872}
# Current buy rate: 0.0
# Current loss: 0.0254, Weights: {'client': 1.9872387636153013, 'buy_intention': -0.44030308039661725, 'discount': -1.4283626566947207, 'nr_visits': -2.1307754231678935}
# Current buy rate: 3.341584158415842
# Current loss: -0.008, Weights: {'client': -1.4547965271623688, 'buy_intention': 0.1528759411633389, 'discount': -2.325878938345748, 'nr_visits': -1.3257839521803627}
# Current buy rate: 0.0
# Current loss: 0.3632, Weights: {'client': -0.7473346540793198, 'buy_intention': 2.4146666640903978, 'discount': -0.7350654771821286, 'nr_visits': -0.4643980312603049}
# Current buy rate: 34.63777928232904
# Current loss: 0.9463, Weights: {'client': -2.0969211176421165, 'buy_intention': 1.4306590805134298, 'discount': 0.9835493688378374, 'nr_visits': 1.8730469290700869}
# Current buy rate: 96.53035935563817
# Current loss: 0.1295, Weights: {'client': -1.1784269580543116, 'buy_intention': 1.9741506692576354, 'discount': -1.036817465797955, 'nr_visits': -1.5886671780238188}
# Current buy rate: 18.03654421595467
# Current loss: 0.1445, Weights: {'client': -0.4765638351856143, 'buy_intention': 1.5765914681294975, 'discount': 0.47375354552100224, 'nr_visits': -2.5996472129886175}
# Current buy rate: 16.3436949480025
# Current loss: 0.1235, Weights: {'client': -2.9708044729580383, 'buy_intention': 2.1929130881689254, 'discount': -0.5512391106071568, 'nr_visits': -2.479114260091227}
# Current buy rate: 11.431989063568011
# Current loss: -0.0064, Weights: {'client': 1.0723759192891518, 'buy_intention': -0.6135632149613679, 'discount': -2.229030189402468, 'nr_visits': -0.8865776740153509}
# Current buy rate: 0.0
# Current loss: -0.0041, Weights: {'client': -1.195242850336868, 'buy_intention': -1.0223490522318675, 'discount': 0.679647658051449, 'nr_visits': -2.476761176496032}
# Current buy rate: 0.01576706785094865
# Current loss: 0.992, Weights: {'client': 1.8627548391415485, 'buy_intention': 1.3540285867597008, 'discount': 0.8866602602905078, 'nr_visits': 0.22282367058070895}
# Current buy rate: 100.0
# Current loss: 0.0251, Weights: {'client': 1.2976024474486534, 'buy_intention': 0.6361133837978725, 'discount': -0.9164149643621454, 'nr_visits': -2.0433783413786957}
# Current buy rate: 2.7182289477371446
# Current loss: 0.6467, Weights: {'client': 0.6633150993882067, 'buy_intention': -1.4578787455149476, 'discount': -1.7490703823736578, 'nr_visits': 2.7164334657530866}
# Current buy rate: 57.03833306823605
# Current loss: 0.0287, Weights: {'client': 1.517218694695126, 'buy_intention': -0.7921756983630899, 'discount': -2.5971994133368206, 'nr_visits': -0.023054055808711005}
# Current buy rate: 0.0
# Current loss: 0.9488, Weights: {'client': -1.9404646053625925, 'buy_intention': -1.3166909285777508, 'discount': 2.2109473453182202, 'nr_visits': 1.9639830009263461}
# Current buy rate: 94.66340959270917
# Current loss: 0.0957, Weights: {'client': -2.9313415195810126, 'buy_intention': 2.661892125224809, 'discount': -1.4365140356379418, 'nr_visits': -2.600553742302324}
# Current buy rate: 9.697426871175928
# Current loss: 0.0453, Weights: {'client': -1.576895349415528, 'buy_intention': 1.034242818510741, 'discount': -0.8314098821074084, 'nr_visits': -1.1214638850818406}
# Current buy rate: 2.512449071978271
# Current loss: 0.9319, Weights: {'client': -2.798832593962904, 'buy_intention': 0.06713537572609307, 'discount': 1.1778224043318173, 'nr_visits': 2.960465385186378}
# Current buy rate: 93.86050126287158
# Current loss: -0.008, Weights: {'client': -0.5321678368900064, 'buy_intention': -1.4046869743477024, 'discount': -0.9287265695331965, 'nr_visits': -2.697170227987372}
# Current buy rate: 0.0
# Current loss: 0.7557, Weights: {'client': -0.09679362075888198, 'buy_intention': 1.63722198773367, 'discount': -0.643973404797586, 'nr_visits': 0.5478665349829981}
# Current buy rate: 60.61471592673083
# Current loss: -0.0079, Weights: {'client': -2.6880704130089614, 'buy_intention': 0.7461731741823685, 'discount': -1.2589810469785863, 'nr_visits': -2.3609765517051584}
# Current buy rate: 0.0
# Current loss: 0.0889, Weights: {'client': -1.4484110246687603, 'buy_intention': 1.3049568340212307, 'discount': -0.007028772435098363, 'nr_visits': -2.112121790277415}
# Current buy rate: 9.887413394919168
# Current loss: 0.5334, Weights: {'client': 0.281889954195927, 'buy_intention': 0.9781477126713201, 'discount': -2.3554820586140788, 'nr_visits': 1.5988708054892988}
# Current buy rate: 59.04023267086767
# Current loss: -0.008, Weights: {'client': -2.9091228475673376, 'buy_intention': 0.3258241949781717, 'discount': -2.715350519563251, 'nr_visits': -0.7192365973364098}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -2.8009088312683073, 'buy_intention': -0.7842420974086979, 'discount': -2.216530938798361, 'nr_visits': -1.2411701856889858}
# Current buy rate: 0.0
# Current loss: 0.3626, Weights: {'client': 1.846531683577315, 'buy_intention': 2.573656587440241, 'discount': -0.8879777401054838, 'nr_visits': -1.1917638673749733}
# Current buy rate: 35.607988279744006
# Current loss: 0.2484, Weights: {'client': -2.8349795152125274, 'buy_intention': -0.46906188385633096, 'discount': 0.5887883400041383, 'nr_visits': -0.5117261359923423}
# Current buy rate: 46.162183466351365
# Current loss: 0.992, Weights: {'client': -0.612346001827648, 'buy_intention': 0.24945165347982923, 'discount': 2.8242643274492183, 'nr_visits': 0.46551242026945294}
# Current buy rate: 100.0
# Current loss: 0.0958, Weights: {'client': -2.9237554244529043, 'buy_intention': 0.28237413341874196, 'discount': -2.4092665163180005, 'nr_visits': 0.9749620419304024}
# Current buy rate: 1.2017047439390762
# Current loss: 0.3907, Weights: {'client': -1.8960647278011753, 'buy_intention': 0.14304746483085795, 'discount': -1.7213128452796043, 'nr_visits': 1.3038851154372533}
# Current buy rate: 22.490941265694783
# Current loss: -0.008, Weights: {'client': -2.932131365986721, 'buy_intention': -1.0516198968774808, 'discount': -2.508558232935471, 'nr_visits': -2.4997284907191197}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -0.9451114653411996, 'buy_intention': 1.1972036602075584, 'discount': -2.623129727410905, 'nr_visits': -1.6130615350362527}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -1.5887727819711426, 'buy_intention': 0.9018344682810673, 'discount': -2.583292692290012, 'nr_visits': -1.8808684859617284}
# Current buy rate: 0.0
# Current loss: 0.4688, Weights: {'client': -1.4002763799935547, 'buy_intention': -1.4738857853081113, 'discount': 0.7638738972011061, 'nr_visits': -0.21268219385129106}
# Current buy rate: 44.987405541561714
# Current loss: -0.008, Weights: {'client': -0.621266255784058, 'buy_intention': 0.14114873459219957, 'discount': -1.9859100954250064, 'nr_visits': -2.068862028566759}
# Current buy rate: 0.0
# Current loss: 0.6882, Weights: {'client': -1.1931198876705715, 'buy_intention': 0.4598559480827966, 'discount': -1.382836718581892, 'nr_visits': 1.5687096866337495}
# Current buy rate: 73.23987701287196
# Current loss: -0.008, Weights: {'client': -2.058741625104908, 'buy_intention': 0.5303502918973382, 'discount': -2.4867651963647504, 'nr_visits': -1.5463887823352345}
# Current buy rate: 0.0
# Current loss: 0.7395, Weights: {'client': -2.7180826206764124, 'buy_intention': 0.17398204968385467, 'discount': 2.035282997084633, 'nr_visits': -1.080321701684499}
# Current buy rate: 88.27916598617236
# Current loss: 0.3436, Weights: {'client': 1.2158073721710736, 'buy_intention': 1.6201685281396663, 'discount': -1.4278892368112144, 'nr_visits': -0.15707920031938483}
# Current buy rate: 26.04794991219363
# Current loss: 0.0313, Weights: {'client': 0.7298792823126492, 'buy_intention': -1.4521999077747103, 'discount': -1.2857372699376173, 'nr_visits': 0.16426135554163124}
# Current buy rate: 0.5657792865225418
# Current loss: 0.9534, Weights: {'client': -2.121734198135017, 'buy_intention': 2.3528997843941095, 'discount': 2.8267168359321317, 'nr_visits': 0.37290129666579963}
# Current buy rate: 94.04902346310132
# Current loss: -0.008, Weights: {'client': -1.4714534465413365, 'buy_intention': 0.021487395741574655, 'discount': -2.9688820017001785, 'nr_visits': -0.09419720081452554}
# Current buy rate: 0.0
# Current loss: 0.0305, Weights: {'client': -1.5441534641897545, 'buy_intention': -0.0651661822093883, 'discount': 0.9898390442142793, 'nr_visits': -2.3020754619588732}
# Current buy rate: 3.1627400514749557
# Current loss: 0.4793, Weights: {'client': -1.7481503846708204, 'buy_intention': -1.6747893197196653, 'discount': -0.7536730315541178, 'nr_visits': 1.3267951545671854}
# Current buy rate: 49.67219832001639
# Current loss: -0.008, Weights: {'client': 0.41607594704820916, 'buy_intention': -0.9453697654036256, 'discount': -1.7483913131035949, 'nr_visits': 0.056386445014302566}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -2.1313573515337367, 'buy_intention': 0.8672783321172783, 'discount': -2.778530315817132, 'nr_visits': -0.76812528802418}
# Current buy rate: 0.0
# Current loss: 0.1144, Weights: {'client': -0.925995818983788, 'buy_intention': 1.2401203800681957, 'discount': 0.20932904202765368, 'nr_visits': -1.9931109195534664}
# Current buy rate: 12.083333333333334
# Current loss: 0.0239, Weights: {'client': -2.7168075844774444, 'buy_intention': 2.434132403637427, 'discount': -2.8789475468522014, 'nr_visits': -2.020556481965547}
# Current buy rate: 2.413475829853493
# Current loss: -0.008, Weights: {'client': 0.5797930003490446, 'buy_intention': 0.007471380004154593, 'discount': -1.0851372740218528, 'nr_visits': -2.2490882628771565}
# Current buy rate: 0.018475750577367205
# Current loss: 0.7445, Weights: {'client': -2.145244444934404, 'buy_intention': -0.5972245261912168, 'discount': 2.4282607754192895, 'nr_visits': -0.9341312263873213}
# Current buy rate: 65.76847809724522
# Current loss: 0.2218, Weights: {'client': -2.065202184540285, 'buy_intention': 1.5190403392496392, 'discount': -0.8110085738873714, 'nr_visits': -0.7026711917087314}
# Current buy rate: 20.36916395222584
# Current loss: 0.4415, Weights: {'client': 2.7528029053049368, 'buy_intention': 0.010034714175943371, 'discount': 2.1105926131843016, 'nr_visits': -2.1547402045505373}
# Current buy rate: 38.65362075115936
# Current loss: -0.0029, Weights: {'client': 1.3321961029126603, 'buy_intention': 0.7247033518198098, 'discount': -2.797917380009482, 'nr_visits': -1.5150509637973146}
# Current buy rate: 1.7427003477022327
# Current loss: 0.1043, Weights: {'client': 1.284991186672739, 'buy_intention': -0.870975500508245, 'discount': -2.033630857696679, 'nr_visits': 0.7835827358422596}
# Current buy rate: 15.370255133789671
# Current loss: 0.673, Weights: {'client': 0.20214162726910478, 'buy_intention': -0.11903884312186386, 'discount': 2.2749901206677245, 'nr_visits': -1.4795988864822263}
# Current buy rate: 39.51672862453531
# Current loss: 0.4695, Weights: {'client': -2.9006683424083413, 'buy_intention': 0.35092905330119684, 'discount': 1.815735651812578, 'nr_visits': -1.6981216732914861}
# Current buy rate: 32.44818263742866
# Current loss: 0.2048, Weights: {'client': -2.770338977698991, 'buy_intention': 1.5175973950861974, 'discount': 0.35567990977369623, 'nr_visits': -1.7955979512267932}
# Current buy rate: 23.967973828074555
# Current loss: 0.0636, Weights: {'client': -1.8113358616098227, 'buy_intention': -0.05852125484460058, 'discount': 0.30972040619006824, 'nr_visits': -0.5814757164831079}
# Current buy rate: 2.1032587527589044
# Current loss: -0.008, Weights: {'client': -0.637711364757593, 'buy_intention': -0.80901545800772, 'discount': -0.89681951450965, 'nr_visits': -1.0463059413464662}
# Current buy rate: 0.0
# Current loss: 0.465, Weights: {'client': 0.42939055362560596, 'buy_intention': 1.0612606951134809, 'discount': -0.2889910692756794, 'nr_visits': -0.16632821582014}
# Current buy rate: 46.50025145156128
# Current loss: -0.008, Weights: {'client': -0.6160125510100294, 'buy_intention': -0.9219226311324611, 'discount': -2.0359401059860764, 'nr_visits': -2.6696457758796983}
# Current buy rate: 0.0
# Current loss: 0.0844, Weights: {'client': 2.0446362667707065, 'buy_intention': 1.0035590770971257, 'discount': -1.5758460129439074, 'nr_visits': -1.197904198254532}
# Current buy rate: 7.644173854219516
# Current loss: -0.008, Weights: {'client': -0.2572375670361169, 'buy_intention': 0.06522487602116245, 'discount': -1.9271638490575447, 'nr_visits': -1.3257839521803627}
# Current buy rate: 0.0
# Current loss: -0.0078, Weights: {'client': -2.7729472333379346, 'buy_intention': 0.5938010122906159, 'discount': -0.7350654771821286, 'nr_visits': -2.6466968301138403}
# Current buy rate: 0.0
# Current loss: 0.0458, Weights: {'client': -0.07909728778673464, 'buy_intention': 1.4306590805134298, 'discount': -1.1646998192896882, 'nr_visits': -1.5833257295160514}
# Current buy rate: 6.901419496510078
# Current loss: -0.008, Weights: {'client': -2.8576429853332814, 'buy_intention': -0.5673387850219546, 'discount': -2.1045241665867724, 'nr_visits': -1.5886671780238188}
# Current buy rate: 0.0
# Current loss: 0.2376, Weights: {'client': -0.6839940197297829, 'buy_intention': 1.1968735366589769, 'discount': -0.6104687498856425, 'nr_visits': -0.511729057325852}
# Current buy rate: 22.898949474737368
# Current loss: 0.1137, Weights: {'client': -0.13767350944946433, 'buy_intention': 2.1929130881689254, 'discount': -2.6250288007632947, 'nr_visits': -0.7301672508456645}
# Current buy rate: 12.81513421124189
# Current loss: 0.5238, Weights: {'client': -1.3303371774688468, 'buy_intention': 1.5707260255574806, 'discount': 1.9855414892394185, 'nr_visits': -2.1124913552588014}
# Current buy rate: 34.26559844622481
# Current loss: 0.0845, Weights: {'client': 1.421760744739505, 'buy_intention': -0.43261193200016956, 'discount': -1.2193544420802649, 'nr_visits': -0.4079943775500854}
# Current buy rate: 10.280119662768561
# Current loss: 0.3009, Weights: {'client': -1.4631455182751185, 'buy_intention': 0.6313719086370693, 'discount': -1.8957067304281086, 'nr_visits': 1.0036325042376688}
# Current buy rate: 8.770030316154179
# Current loss: 0.0973, Weights: {'client': 2.3056542424541533, 'buy_intention': 0.3685881134090665, 'discount': -0.9164149643621454, 'nr_visits': -0.5414236894143908}
# Current buy rate: 9.974437371560322
# Current loss: 0.1546, Weights: {'client': 0.6473209172646797, 'buy_intention': 2.0654248247388636, 'discount': -2.12336056550686, 'nr_visits': -0.7966745144279958}
# Current buy rate: 18.853414122582148
# Current loss: 0.0704, Weights: {'client': 1.488301796115403, 'buy_intention': 0.36777783526915075, 'discount': -2.252735640526062, 'nr_visits': -0.023054055808711005}
# Current buy rate: 5.704071287551358
# Current loss: 0.9806, Weights: {'client': 1.7353861845456722, 'buy_intention': -1.3166909285777508, 'discount': 2.2109473453182202, 'nr_visits': 1.0451496060032832}
# Current buy rate: 95.28624766645925
# Current loss: -0.008, Weights: {'client': 0.07668973790583644, 'buy_intention': -0.5714973705845403, 'discount': -2.906263092961125, 'nr_visits': -2.600553742302324}
# Current buy rate: 0.0
# Current loss: 0.6788, Weights: {'client': 1.963882242788387, 'buy_intention': -0.032091614236079535, 'discount': -0.8314098821074084, 'nr_visits': 0.930823683918637}
# Current buy rate: 45.21569042080778
# Current loss: -0.008, Weights: {'client': -2.8065632810704013, 'buy_intention': -1.0494521006634958, 'discount': -1.9121299432698882, 'nr_visits': -0.6167419106555684}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -0.44436904527462207, 'buy_intention': -0.6559098286020403, 'discount': -1.7782209698986988, 'nr_visits': -0.5447319132391859}
# Current buy rate: 0.0
# Current loss: 0.0711, Weights: {'client': -2.131484736572548, 'buy_intention': 0.01943715145661762, 'discount': -2.281893460204016, 'nr_visits': 0.918156641741811}
# Current buy rate: 11.430464673237802
# Current loss: -0.0079, Weights: {'client': -0.08712106266368191, 'buy_intention': -0.16947958145719277, 'discount': 0.10951863024342856, 'nr_visits': -1.5204039554165407}
# Current buy rate: 0.0
# Current loss: 0.306, Weights: {'client': -1.4484110246687603, 'buy_intention': 1.09658791618813, 'discount': -2.657981107671346, 'nr_visits': 1.2883926305119735}
# Current buy rate: 18.846072857443673
# Current loss: 0.992, Weights: {'client': 0.15700288080771974, 'buy_intention': 1.013235426743248, 'discount': 2.2593557868287446, 'nr_visits': -0.3517489501609645}
# Current buy rate: 99.84626066256695
# Current loss: -0.008, Weights: {'client': -2.7364060082520143, 'buy_intention': 0.2924426247686678, 'discount': -2.715350519563251, 'nr_visits': -0.44976172595707076}
# Current buy rate: 0.0
# Current loss: 0.8907, Weights: {'client': -0.37712904431505545, 'buy_intention': 0.23408395031347373, 'discount': -0.016889324149921503, 'nr_visits': 0.09290777239155812}
# Current buy rate: 90.07488479262673
# Current loss: 0.0783, Weights: {'client': 0.4587934128957061, 'buy_intention': -2.505018444327088, 'discount': -1.4577983116123905, 'nr_visits': 0.6897536019096908}
# Current buy rate: 2.865866352092152
# Current loss: 0.6234, Weights: {'client': -1.285598053035171, 'buy_intention': 1.5581025105171484, 'discount': 2.369185913790629, 'nr_visits': -2.036574121505409}
# Current buy rate: 77.7707772495561
# Current loss: 0.6038, Weights: {'client': -2.886969416424114, 'buy_intention': -1.4564070453659896, 'discount': 1.063918863689651, 'nr_visits': 0.14450006881682298}
# Current buy rate: 65.22807556442942
# Current loss: 0.0549, Weights: {'client': -0.9958163222039317, 'buy_intention': 0.28237413341874196, 'discount': -2.816041467473942, 'nr_visits': 0.9749620419304024}
# Current buy rate: 0.1421161088609394
# Current loss: -0.008, Weights: {'client': -0.4177413120096518, 'buy_intention': -2.989878260239136, 'discount': -1.4862619473398149, 'nr_visits': -1.769494621745029}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -2.4731732059935627, 'buy_intention': -0.2094815328363866, 'discount': -1.772825587652271, 'nr_visits': -1.4546547644181005}
# Current buy rate: 0.0
# Current loss: 0.0339, Weights: {'client': 0.4143688962912664, 'buy_intention': 2.5903539616283906, 'discount': -2.623129727410905, 'nr_visits': -2.6471041376740096}
# Current buy rate: 2.319696330662168
# Current loss: 0.0938, Weights: {'client': -1.5887727819711426, 'buy_intention': 1.9681563622421538, 'discount': -1.160332176591993, 'nr_visits': -1.8808684859617284}
# Current buy rate: 5.899848583171101
# Current loss: 0.8834, Weights: {'client': -1.0361079124843908, 'buy_intention': -0.9023928265491059, 'discount': 2.764542933260951, 'nr_visits': -0.4678522361172811}
# Current buy rate: 97.56777864554279
# Current loss: -0.008, Weights: {'client': -1.448639382028977, 'buy_intention': 0.14114873459219957, 'discount': -0.48104399080910976, 'nr_visits': -2.068862028566759}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -1.1931198876705715, 'buy_intention': 0.4598559480827966, 'discount': -1.37058140060178, 'nr_visits': -1.6994253972235815}
# Current buy rate: 0.0
# Current loss: 0.2438, Weights: {'client': -2.048588447294518, 'buy_intention': 1.9073338670750002, 'discount': -0.014309150778670565, 'nr_visits': -1.5463887823352345}
# Current buy rate: 25.479959582350958
# Current loss: 0.8385, Weights: {'client': -2.7180826206764124, 'buy_intention': 0.17398204968385467, 'discount': 2.553627752595263, 'nr_visits': -0.9910336494213045}
# Current buy rate: 68.16282997066926
# Current loss: 0.0218, Weights: {'client': -2.2267656958095667, 'buy_intention': 0.7156546588482693, 'discount': -1.4324399479789345, 'nr_visits': -0.15707920031938483}
# Current buy rate: 0.0
# Current loss: 0.9829, Weights: {'client': 0.7298792823126492, 'buy_intention': 0.10841117966051272, 'discount': 1.8575391685862577, 'nr_visits': -0.4732022751384428}
# Current buy rate: 99.90063757555684
# Current loss: -0.008, Weights: {'client': -2.0312655094159107, 'buy_intention': -2.055181921730659, 'discount': -0.40798729706775827, 'nr_visits': -0.3861832233440373}
# Current buy rate: 0.0
# Current loss: 0.0747, Weights: {'client': -1.009844702149915, 'buy_intention': 2.407073063422075, 'discount': -2.9688820017001785, 'nr_visits': -1.0220438888951988}
# Current buy rate: 0.14925959385678936
# Current loss: -0.0079, Weights: {'client': -0.38332175579726213, 'buy_intention': 0.5379384821328836, 'discount': -1.0749301848071833, 'nr_visits': -1.4174155374665298}
# Current buy rate: 0.0
# Current loss: 0.5328, Weights: {'client': -2.8127157070807534, 'buy_intention': -1.6747893197196653, 'discount': 0.30887255008748893, 'nr_visits': 0.44433737065611867}
# Current buy rate: 54.090171633506955
# Current loss: -0.008, Weights: {'client': -1.0140659600297524, 'buy_intention': -0.9453697654036256, 'discount': -1.7483913131035949, 'nr_visits': -1.5758200835659546}
# Current buy rate: 0.0
# Current loss: 0.0, Weights: {'client': -2.1313573515337367, 'buy_intention': -0.8623774471011645, 'discount': -2.361667990502995, 'nr_visits': 0.6403524440601407}
# Current buy rate: 0.046582042622569
# Current loss: 0.2395, Weights: {'client': -0.925995818983788, 'buy_intention': 0.6470459370729396, 'discount': 0.20932904202765368, 'nr_visits': -0.7515148299334734}
# Current buy rate: 23.73892773892774
# Current loss: -0.008, Weights: {'client': -2.5421645118444767, 'buy_intention': -0.0450072075748843, 'discount': -2.447026652500858, 'nr_visits': -2.1680091510959754}
# Current buy rate: 0.0
# Current loss: 0.0265, Weights: {'client': 0.5797930003490446, 'buy_intention': 1.445113015596117, 'discount': -1.0851372740218528, 'nr_visits': -2.277816126033444}
# Current buy rate: 4.461197683907823
# Current loss: -0.0028, Weights: {'client': -2.0968138999314636, 'buy_intention': 0.7406524942876844, 'discount': -0.5731854634386222, 'nr_visits': -1.870841593553478}
# Current buy rate: 0.17005545286506468
# Current loss: 0.0031, Weights: {'client': 0.929856829066668, 'buy_intention': 0.7435938628534391, 'discount': -0.8110085738873714, 'nr_visits': -2.4618811910032568}
# Current buy rate: 0.7549457210558219
# Current loss: -0.008, Weights: {'client': -1.415683022648893, 'buy_intention': -0.17699928055092218, 'discount': -2.524691768742384, 'nr_visits': -1.4547144560665248}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -2.024724246091509, 'buy_intention': 0.266837068810148, 'discount': -2.122659119840444, 'nr_visits': -0.44971467140461696}
# Current buy rate: 0.0
# Current loss: 0.1107, Weights: {'client': 2.931050510618407, 'buy_intention': -0.12418324229579736, 'discount': -2.033630857696679, 'nr_visits': 0.6247913317410332}
# Current buy rate: 10.493444576877236
# Current loss: -0.008, Weights: {'client': -0.6453344730572024, 'buy_intention': -0.11903884312186386, 'discount': -2.1940042052267703, 'nr_visits': -0.6237228230132112}
# Current buy rate: 0.0
# Current loss: 0.2905, Weights: {'client': 1.6688489902385286, 'buy_intention': -0.2560313283747748, 'discount': 0.8106458593014236, 'nr_visits': -0.9415850951594268}
# Current buy rate: 17.483850471248545
# Current loss: -0.008, Weights: {'client': -2.770338977698991, 'buy_intention': -1.0810868359951011, 'discount': -0.6383816414380263, 'nr_visits': -0.22636995858255404}
# Current buy rate: 0.0
# Current loss: -0.0079, Weights: {'client': -2.7505909999159686, 'buy_intention': -0.05852125484460058, 'discount': 0.30972040619006824, 'nr_visits': -2.949946970881073}
# Current buy rate: 0.0070057447106627434
# Current loss: 0.1066, Weights: {'client': -1.592513543610702, 'buy_intention': 1.3101918115508995, 'discount': -2.748250832374432, 'nr_visits': 0.4573288479464812}
# Current buy rate: 0.10526315789473684
# Current loss: 0.0013, Weights: {'client': -1.9582679807080317, 'buy_intention': -0.9037338248464568, 'discount': -2.620494786810828, 'nr_visits': 0.7248316542155948}
# Current buy rate: 0.08875739644970414
# Current loss: -0.008, Weights: {'client': -0.6731562364107173, 'buy_intention': 0.6838513672936006, 'discount': -2.0359401059860764, 'nr_visits': -2.6696457758796983}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -2.3105790147522476, 'buy_intention': -0.5409522394350355, 'discount': -1.4283626566947207, 'nr_visits': -2.1656132610669516}
# Current buy rate: 0.0
# Current loss: 0.4574, Weights: {'client': -2.24630571270331, 'buy_intention': 0.023491587910245304, 'discount': 1.5546352358570248, 'nr_visits': -1.3257839521803627}
# Current buy rate: 58.41225728599115
# Current loss: -0.008, Weights: {'client': -2.7729472333379346, 'buy_intention': -0.3372203004894416, 'discount': -0.9636476503964304, 'nr_visits': -0.678497987218996}
# Current buy rate: 0.0
# Current loss: 0.376, Weights: {'client': -2.2613281866209034, 'buy_intention': -1.0884469006806132, 'discount': -0.5231513077968541, 'nr_visits': 0.7262941523599984}
# Current buy rate: 30.502862008609675
# Current loss: 0.9877, Weights: {'client': -0.5367651187024958, 'buy_intention': 1.5531173717301425, 'discount': 0.4817378017366378, 'nr_visits': 0.9269464298170322}
# Current buy rate: 99.91901959725746
# Current loss: 0.1216, Weights: {'client': -0.9536560140132833, 'buy_intention': 0.9381623807147237, 'discount': 0.47375354552100224, 'nr_visits': -1.8659863645551271}
# Current buy rate: 16.191601437503078
# Current loss: 0.992, Weights: {'client': 1.5566534614775427, 'buy_intention': 2.1929130881689254, 'discount': 1.5173642197159964, 'nr_visits': 0.25708639254536925}
# Current buy rate: 100.0
# Current loss: -0.008, Weights: {'client': -0.41321844229706395, 'buy_intention': -0.7908329433390089, 'discount': -2.637752493509584, 'nr_visits': -0.32493771573158936}
# Current buy rate: 0.0
# Current loss: 0.519, Weights: {'client': -2.6684507155833677, 'buy_intention': 0.2510733963206775, 'discount': -2.6048054282455384, 'nr_visits': 2.445860527271013}
# Current buy rate: 45.59937477455813
# Current loss: 0.0988, Weights: {'client': -0.9296076311340705, 'buy_intention': -0.4551376723048035, 'discount': -1.9766171671640458, 'nr_visits': 1.0036325042376688}
# Current buy rate: 16.85443605172193
# Current loss: 0.2142, Weights: {'client': 1.2198057044720023, 'buy_intention': 0.1363092072407781, 'discount': -2.619572109986687, 'nr_visits': 1.2183955577292511}
# Current buy rate: 18.056171939390097
# Current loss: 0.0301, Weights: {'client': 0.6473209172646797, 'buy_intention': 2.0654248247388636, 'discount': -2.12336056550686, 'nr_visits': -2.2996669782816395}
# Current buy rate: 3.5828357172614913
# Current loss: -0.008, Weights: {'client': -1.574599655690397, 'buy_intention': -1.3001554174828382, 'discount': -2.4570225054802908, 'nr_visits': -0.613535717050338}
# Current buy rate: 0.0
# Current loss: 0.9687, Weights: {'client': -0.5893675268605103, 'buy_intention': 0.7650514615910782, 'discount': 2.690171202238595, 'nr_visits': -0.7716605446678442}
# Current buy rate: 94.7094836548458
# Current loss: 0.1674, Weights: {'client': -0.7709420407783822, 'buy_intention': -1.3708565000013828, 'discount': -1.390789337871791, 'nr_visits': 0.9933645768804862}
# Current buy rate: 37.473564340328615
# Current loss: -0.008, Weights: {'client': 0.0012825526611401905, 'buy_intention': -1.016932521691914, 'discount': -2.964413001092291, 'nr_visits': -1.5681462750748612}
# Current buy rate: 0.0
# Current loss: 0.0228, Weights: {'client': 1.183513795372057, 'buy_intention': -0.9732172609798132, 'discount': -2.1219394204194213, 'nr_visits': 0.023404951567014498}
# Current buy rate: 6.903014212088084
# Current loss: 0.0731, Weights: {'client': 0.2706939758150666, 'buy_intention': -2.162995339210897, 'discount': -1.7782209698986988, 'nr_visits': 0.8768775604565153}
# Current buy rate: 5.563572230238897
# Current loss: -0.008, Weights: {'client': -0.0744202283024189, 'buy_intention': -0.6049121965081035, 'discount': -2.281893460204016, 'nr_visits': -0.046021504171891436}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': 0.4277825073920454, 'buy_intention': -0.9732172609798132, 'discount': -2.1219394204194213, 'nr_visits': 0.023404951567014498}
# Current buy rate: 0.0
# Current loss: 0.4282, Weights: {'client': -1.3531281243826325, 'buy_intention': 0.5611683234507245, 'discount': 1.985601696705883, 'nr_visits': -2.112121790277415}
# Current buy rate: 38.11450536111673
# Current loss: 0.3062, Weights: {'client': -2.532439482417206, 'buy_intention': 0.8751768567357072, 'discount': -2.8970488465000583, 'nr_visits': 1.5988708054892988}
# Current buy rate: 58.079462527510714
# Current loss: 0.9879, Weights: {'client': -0.3188007149589489, 'buy_intention': 0.2924426247686678, 'discount': 2.245317590014862, 'nr_visits': -0.44976172595707076}
# ...
# Current buy rate: 20.25792273883877
# Current loss: -0.008, Weights: {'client': 0.6558200006886663, 'buy_intention': 0.20118879458075867, 'discount': -1.601629144800563, 'nr_visits': -2.426216310139755}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -1.1356325527317637, 'buy_intention': -1.7002895848075283, 'discount': -2.2023044893466457, 'nr_visits': -1.3881911212813007}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -0.4177413120096518, 'buy_intention': -1.4171728719119352, 'discount': -1.975370967791164, 'nr_visits': -0.2806806878167385}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -1.3183090720499657, 'buy_intention': -1.7315242230436696, 'discount': -2.260816348188012, 'nr_visits': -1.5629592253800544}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -0.5672302017008997, 'buy_intention': -0.9290468064342561, 'discount': -2.623129727410905, 'nr_visits': -0.24163855890066077}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -1.0522042869874857, 'buy_intention': -1.5550735900331445, 'discount': -2.8107348362409255, 'nr_visits': -2.3314623210881287}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -0.8137924611199248, 'buy_intention': 0.10439402129628705, 'discount': -2.7499610651122715, 'nr_visits': -0.6737982827494307}
# Current buy rate: 0.0
# Current loss: 0.0011, Weights: {'client': -1.6861144259972602, 'buy_intention': -1.1578080219168465, 'discount': -2.511866942727721, 'nr_visits': 0.6779146751995588}
# Current buy rate: 0.009707795359673818
# Current loss: -0.008, Weights: {'client': -2.2443567590302163, 'buy_intention': -2.8100965548681947, 'discount': -1.0864841841534272, 'nr_visits': 0.022784736023320873}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -2.058741625104908, 'buy_intention': -1.2144918005267058, 'discount': -2.4867651963647504, 'nr_visits': -1.0845386170791516}
# Current buy rate: 0.0
# Current loss: 0.8611, Weights: {'client': 0.002637141751669292, 'buy_intention': -1.5605935099021682, 'discount': 2.484206169081939, 'nr_visits': -0.0023068702288925325}
# Current buy rate: 100.0
# Current loss: -0.008, Weights: {'client': -0.7639867617564917, 'buy_intention': -0.5193492746670827, 'discount': -2.545730349760694, 'nr_visits': -2.4604689143489624}
# Current buy rate: 0.0
# Current loss: 0.0089, Weights: {'client': 1.1077864720991977, 'buy_intention': -0.2004042799120107, 'discount': -1.2857372699376173, 'nr_visits': -1.0915884576737522}
# Current buy rate: 4.833816934845688
# Current loss: 0.1069, Weights: {'client': -2.0312655094159107, 'buy_intention': 2.567903455080735, 'discount': -1.7147099218914468, 'nr_visits': -2.0232917566759374}
# Current buy rate: 17.8305838105821
# Current loss: -0.008, Weights: {'client': -0.8983063669905191, 'buy_intention': -2.144405027769338, 'discount': -2.3987464424279525, 'nr_visits': -2.5645239964598066}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -2.258410098799491, 'buy_intention': -1.7736798855393445, 'discount': -2.291042217384085, 'nr_visits': -1.9779774144918116}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -2.299641055041921, 'buy_intention': 0.4454717628273328, 'discount': -2.460061218346313, 'nr_visits': -2.071540590566}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -2.252068572502608, 'buy_intention': 0.2154879708900621, 'discount': -2.7465185474911085, 'nr_visits': -0.9121189410117132}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -1.0769500781228725, 'buy_intention': -1.7015669041239811, 'discount': -2.778530315817132, 'nr_visits': -1.3084060281657002}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -0.9935597845359969, 'buy_intention': -2.5660946652797447, 'discount': -2.889748345122274, 'nr_visits': -1.0077091872467656}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -1.6937185194474222, 'buy_intention': 0.4649784146339462, 'discount': -2.9092671378336994, 'nr_visits': -2.207558509362749}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -1.1903543878768663, 'buy_intention': -0.9776347402272019, 'discount': -2.932119705247813, 'nr_visits': -1.6993464114353274}
# Current buy rate: 0.0
# Current loss: 0.2668, Weights: {'client': -1.5145806265881023, 'buy_intention': -0.696270160297936, 'discount': 1.866862811893835, 'nr_visits': -1.7663895622732366}
# Current buy rate: 7.828105598445176
# Current loss: -0.008, Weights: {'client': -2.6946619639715284, 'buy_intention': -1.170100809593464, 'discount': -2.739849759174292, 'nr_visits': -1.229208887803497}
# Current buy rate: 0.0
# Current loss: 0.4494, Weights: {'client': -1.1435479170131653, 'buy_intention': -1.8433741281259943, 'discount': 1.6481430492035376, 'nr_visits': -0.7069951444394661}
# Current buy rate: 55.44880028772543
# Current loss: -0.008, Weights: {'client': -2.2638221263925757, 'buy_intention': 0.266837068810148, 'discount': -0.812124109059853, 'nr_visits': -0.4677615463833369}
# Current buy rate: 0.0
# Current loss: -0.0076, Weights: {'client': -2.273212633022246, 'buy_intention': -0.5446511471713829, 'discount': -2.3385671096037366, 'nr_visits': 0.37255320358629884}
# Current buy rate: 0.0
# Current loss: -0.0033, Weights: {'client': -2.028305686666263, 'buy_intention': -0.8299563929984275, 'discount': -2.546685774889318, 'nr_visits': 0.6429520110535578}
# Current buy rate: 1.8579234972677594
# Current loss: -0.008, Weights: {'client': -2.4087492258689367, 'buy_intention': -1.041666769995269, 'discount': -1.6686617592240183, 'nr_visits': -1.6436441724610473}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': 0.14089878914059306, 'buy_intention': -1.1305488163309743, 'discount': -1.9978118730569228, 'nr_visits': -0.5052050251954148}
# Current buy rate: 0.0
# Current loss: 0.1528, Weights: {'client': -2.426904876312778, 'buy_intention': -2.108046725681178, 'discount': 2.5609645176922644, 'nr_visits': -2.949946970881073}
# Current buy rate: 17.809968082494475
# Current loss: 0.1796, Weights: {'client': -1.97769539829107, 'buy_intention': -1.4881414881716382, 'discount': 1.5656508731134213, 'nr_visits': -1.609615749760899}
# Current buy rate: 16.038850242814018
# Current loss: 0.032, Weights: {'client': 2.042042124867019, 'buy_intention': -2.9320214132171323, 'discount': -2.551155161594017, 'nr_visits': -0.3774431851366058}
# Current buy rate: 1.4789118130363337
# Current loss: -0.008, Weights: {'client': -0.4159928193411756, 'buy_intention': -2.1703717043265485, 'discount': -1.9374927658523622, 'nr_visits': -2.6696457758796983}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -2.033933409465132, 'buy_intention': -1.9217368701047768, 'discount': -2.611374375061805, 'nr_visits': -0.48825343845401004}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -0.6538226253241838, 'buy_intention': 0.06522487602116245, 'discount': -1.7899764071039632, 'nr_visits': -1.862674284756745}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -1.4966091291199557, 'buy_intention': 0.4818753408941736, 'discount': -2.136463045588228, 'nr_visits': -2.5181483569467287}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -1.0404848139190792, 'buy_intention': -1.3883461671914574, 'discount': -2.420103820818387, 'nr_visits': -0.053303242479305846}
# Current buy rate: 0.0
# Current loss: 0.1325, Weights: {'client': 0.9236931019385775, 'buy_intention': 0.8800411761651199, 'discount': 0.01965570416909257, 'nr_visits': -1.5886671780238188}
# Current buy rate: 14.838093722650965
# Current loss: -0.0063, Weights: {'client': -2.3060627412686707, 'buy_intention': -1.7441366434269219, 'discount': 0.43791562567094955, 'nr_visits': -2.0841228668933995}
# Current buy rate: 0.12091898428053204
# Current loss: -0.008, Weights: {'client': -0.8838016513364122, 'buy_intention': -1.3152768819748335, 'discount': -2.0910714080376156, 'nr_visits': -2.479509424595218}
# Current buy rate: 0.0
# Current loss: 0.2148, Weights: {'client': -2.892232908260784, 'buy_intention': -2.116633317637946, 'discount': 1.643803052463694, 'nr_visits': -1.4257729702784627}
# Current buy rate: 6.154981549815498
# Current loss: -0.008, Weights: {'client': -2.1572777387716604, 'buy_intention': -1.2565940466457066, 'discount': -1.003291357518021, 'nr_visits': -1.861731161145547}
# Current buy rate: 0.0
# Current loss: 0.2714, Weights: {'client': 0.05603681956259465, 'buy_intention': 0.8051625882035531, 'discount': -0.9862300760704974, 'nr_visits': 0.13843114640070464}
# Current buy rate: 16.207551650439324
# Current loss: 0.1557, Weights: {'client': -2.385997937633216, 'buy_intention': 1.052009410622787, 'discount': -1.071722563128957, 'nr_visits': -0.29589644081887523}
# Current buy rate: 27.055429631155985
# Current loss: 0.0224, Weights: {'client': 1.5080223808020228, 'buy_intention': 0.8302865105700241, 'discount': -2.872395073240949, 'nr_visits': -0.7140268716381196}
# Current buy rate: 3.0408600009953717
# Current loss: 0.5341, Weights: {'client': -2.30471652584655, 'buy_intention': -0.2776852006899919, 'discount': -2.522706883510116, 'nr_visits': 2.6639540961532506}
# Current buy rate: 60.53984575835476
# Current loss: 0.0384, Weights: {'client': -2.100165080509904, 'buy_intention': 2.936332701724853, 'discount': -2.8285844299065546, 'nr_visits': -2.7142494106955377}
# Current buy rate: 4.798905125601519
# Current loss: -0.008, Weights: {'client': 0.07668973790583644, 'buy_intention': -1.8213825770646002, 'discount': -2.5948233587638017, 'nr_visits': -1.1796048255860097}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -1.6723565039227677, 'buy_intention': -1.1443053345353047, 'discount': -1.4977846319945913, 'nr_visits': -1.5419007731254764}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -2.663799100952504, 'buy_intention': -0.9091015310337256, 'discount': -2.601169499671665, 'nr_visits': -0.5438808925003169}
# Current buy rate: 0.0
# Current loss: 0.0157, Weights: {'client': 2.3225845919944943, 'buy_intention': -2.5531278650358513, 'discount': -2.2232224278545667, 'nr_visits': -1.794386050179229}
# Current buy rate: 2.168422349534898
# Current loss: -0.0041, Weights: {'client': -1.9622583910662212, 'buy_intention': -1.900450870767539, 'discount': 0.5049663692904851, 'nr_visits': -1.780648501834625}
# Current buy rate: 0.15778401122019636
# Current loss: -0.008, Weights: {'client': 0.4277825073920454, 'buy_intention': -1.1038921053215673, 'discount': -2.1219394204194213, 'nr_visits': -1.0940868754269297}
# Current buy rate: 0.0
# Current loss: 0.6352, Weights: {'client': 1.8815720553243678, 'buy_intention': 0.3095863497171738, 'discount': 2.3942901227726203, 'nr_visits': -1.9339930149078652}
# Current buy rate: 38.121851928517216
# Current loss: -0.008, Weights: {'client': 0.5301229740523581, 'buy_intention': -1.8172712578330312, 'discount': -2.8970488465000583, 'nr_visits': -1.821385050947562}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -2.8846849269952113, 'buy_intention': -1.9489096582395442, 'discount': -2.1525273713779747, 'nr_visits': -1.8073847024453025}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -2.143542764676881, 'buy_intention': -2.3323255284592794, 'discount': -2.463186351229327, 'nr_visits': -1.658673252256186}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -0.9332418777120742, 'buy_intention': -0.42968285329919975, 'discount': -2.268522131294832, 'nr_visits': -1.5756001149802952}
# Current buy rate: 0.0
# Current loss: -0.008, Weights: {'client': -0.10141357074614099, 'buy_intention': 0.3588000598382455, 'discount': -1.9327423786589697, 'nr_visits': -2.816515857284356}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[233], line 1
# ----> 1 optimal_weights = optimize_weights(nr_agents=10000, target_sum=80, threshold=0.5, model='polynomial')
#       3 print("Optimal Weights:", optimal_weights)
#
# Cell In[232], line 59, in optimize_weights(nr_agents, target_sum, threshold, model)
#      56 bounds = [(-3, 3), (-3, 3), (-3, 3), (-3, 3)]
#      58 # Run the differential evolution algorithm
# ---> 59 result = differential_evolution(objective_function, bounds)
#      61 # Convert the result back to a dictionary
#      62 optimal_weights = {
#      63     'client': result.x[0],
#      64     'buy_intention': result.x[1],
#      65     'discount': result.x[2],
#      66     'nr_visits': result.x[3]
#      67 }
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\optimize\_differentialevolution.py:402, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     385 # using a context manager means that any created Pool objects are
#     386 # cleared up.
#     387 with DifferentialEvolutionSolver(func, bounds, args=args,
#     388                                  strategy=strategy,
#     389                                  maxiter=maxiter,
#    (...)
#     400                                  integrality=integrality,
#     401                                  vectorized=vectorized) as solver:
# --> 402     ret = solver.solve()
#     404 return ret
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\optimize\_differentialevolution.py:1022, in DifferentialEvolutionSolver.solve(self)
#    1019 for nit in range(1, self.maxiter + 1):
#    1020     # evolve the population by a generation
#    1021     try:
# -> 1022         next(self)
#    1023     except StopIteration:
#    1024         warning_flag = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\optimize\_differentialevolution.py:1409, in DifferentialEvolutionSolver.__next__(self)
#    1407     feasible = True
#    1408     cv = np.atleast_2d([0.])
# -> 1409     energy = self.func(parameters)
#    1410     self._nfev += 1
#    1412 # compare trial and population member
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\_lib\_util.py:360, in _FunctionWrapper.__call__(self, x)
#     359 def __call__(self, x):
# --> 360     return self.f(x, *self.args)
#
# Cell In[232], line 41, in optimize_weights.<locals>.objective_function(weights_array)
#      39 loss = (sum_buy_decisions - target_sum) / len(buy_decisions)
#      40 print(f"Current loss: {loss}, Weights: {weights}")
# ---> 41 buy_rate = compute_buy_rate_per_day(weights=weights, model=model)
#      42 print(f"Current buy rate: {buy_rate}")
#      43 return loss
#
# Cell In[179], line 14, in compute_buy_rate_per_day(weights, nr_agents_mean, nr_agents_std, model, threshold)
#      12     buy_decision = will_buy_linear(agents[i], discount_sample, weights, threshold=threshold)
#      13 elif model == 'polynomial':
# ---> 14     buy_decision = will_buy_polynomial(agents[i], discount_sample, weights, threshold=threshold)
#      15 else:
#      16     return "Model unrecognized"
#
# Cell In[211], line 22, in will_buy_polynomial(agent, discount, weights, threshold)
#       2 """
#       3 Polynomial model for predicting purchase decision based on input features.
#       4
#    (...)
#      12 - buy_decision (bool): True if the client is predicted to buy, False otherwise.
#      13 """
#      15 weighted_sum = (
#      16     weights['buy_intention'] * (agent[0] ** 3) +
#      17     weights['nr_visits'] * ((agent[2] / 100) ** 2) +
#      18     weights['client'] * agent[1] +
#      19     weights['discount'] * discount
#      20 )
# ---> 22 buy_probability = torch.sigmoid(torch.tensor(weighted_sum))
#      24 buy_decision = buy_probability.item() > threshold
#      26 return buy_decision
#
# KeyboardInterrupt:

# %% [markdown]
# ## Multi armed bandits
#
# 10 zile, cate un esantion de agenti in fiecare zi
# 3 discounturi (bandits)
